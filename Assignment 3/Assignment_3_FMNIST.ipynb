# %%
import os
import numpy as np
import time
import tensorflow as tf
import datetime
import matplotlib.pyplot as plt
seed = 5693
np.random.seed(seed)
tf.random.set_seed(seed)
NUM_OF_CATEGORY = 10

# %%
mnist = tf.keras.datasets.fashion_mnist
# mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_final_test, y_final_test = x_test, y_test

x_test = x_train[50000:60000]
x_train = x_train[0:50000]
y_test = y_train[50000:60000]
y_train = y_train[0:50000]

x_train, x_test, x_final_test = np.reshape(x_train / 255.0, (int(tf.shape(x_train)[0]),-1)), np.reshape(x_test / 255.0, (int(tf.shape(x_test)[0]),-1)), np.reshape(x_final_test / 255.0, (int(tf.shape(x_final_test)[0]),-1))
one_hot_y = lambda t: [1 if i == t else 0 for i in range(NUM_OF_CATEGORY)]
y_train, y_test, y_final_test = np.array([one_hot_y(y) for y in y_train]), np.array([one_hot_y(y) for y in y_test]), np.array([one_hot_y(y) for y in y_final_test])

# %%
class MLP(tf.keras.Model):
    def __init__(self, size_input, size_hidden, size_output, device=None):
        super(MLP, self).__init__()
        """
        size_input: int, size of input layer
        size_hidden: int, size of hidden layer
        size_output: int, size of output layer
        device: str or None, either 'cpu' or 'gpu' or None. If None, the device to be used will be decided automatically during Eager Execution
        """
        self.size_input, self.size_hidden, self.size_output, self.device =\
        size_input, size_hidden, size_output, device

        # Initialize weights between input layer and hidden layer 1
        self.W1 = tf.Variable(tf.random.normal([self.size_input, self.size_hidden], seed=seed, stddev=0.1))
        # Initialize biases for hidden layer 1
        self.b1 = tf.Variable(tf.random.normal([1, self.size_hidden], seed=seed))
         # Initialize weights between hidden layer 1 and hidden layer 2
        self.W2 = tf.Variable(tf.random.normal([self.size_hidden, self.size_hidden], seed=seed, stddev=0.1))
        # Initialize biases for hidden layer 2
        self.b2 = tf.Variable(tf.random.normal([1, self.size_hidden], seed=seed))
         # Initialize weights between hidden layer 2 and output layer
        self.W3 = tf.Variable(tf.random.normal([self.size_hidden, self.size_output], seed=seed, stddev=0.1))
        # Initialize biases for output layer
        self.b3 = tf.Variable(tf.random.normal([1, self.size_output], seed=seed))

        # Define variables to be updated during backpropagation
        self.MLP_variables = [self.W1, self.W2, self.W3, self.b1, self.b2, self.b3]
        # self.MLP_variables = [self.W1, self.W3, self.b1, self.b3]
        
        # Initialize parameters for Stochastic optimization
        self.beta1 = 0.9
        self.beta2 = 0.999
        self.beta3 = 0.999987
        self.epsilon = pow(10,-8)
        # Initialize variables for Stochastic optimization
        self.t = 0
        self.m = []
        self.v = []
        self.u = []
        for var in self.MLP_variables:
            self.m.append(tf.Variable(tf.zeros_like(var), trainable=False))
            self.v.append(tf.Variable(tf.zeros_like(var), trainable=False))
            self.u.append(tf.Variable(tf.zeros_like(var), trainable=False))
        
    
    def forward(self, X, dropout_rate=0):
        """
        forward pass
        X: Tensor, inputs
        """
        if self.device is not None:
            with tf.device('gpu:0' if self.device=='gpu' else 'cpu'):
                self.y = self.compute_output(X, dropout_rate=dropout_rate)
        else:
            self.y = self.compute_output(X, dropout_rate=dropout_rate)

        return self.y
  
    def loss(self, y_pred, y_true, L1=0, L2=0):
        '''
        y_pred - Tensor of shape (batch_size, size_output)
        y_true - Tensor of shape (batch_size, size_output)
        '''
        y_true_tf = tf.cast(tf.reshape(y_true, (-1, self.size_output)), dtype=tf.float32)
        y_pred_tf = tf.cast(y_pred, dtype=tf.float32)
        l2_penlty = (tf.nn.l2_loss(self.W1)+tf.nn.l2_loss(self.W2)+tf.nn.l2_loss(self.W3))*L2
        loss_with_l2 = l2_penlty+tf.losses.categorical_crossentropy(y_true_tf, y_pred_tf)
#         print("y_true_tf",y_true_tf,"y_pred_tf",y_pred_tf)
        return loss_with_l2
  
    def backward(self, X_train, y_train, dropout_rate, learning_rate, L1=0, L2=0):
        """
        backward pass
        """
        optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
        with tf.GradientTape() as tape:
            predicted = self.forward(X_train,dropout_rate=dropout_rate)
            current_loss = self.loss(predicted, y_train, L2=L2)
        grads = tape.gradient(current_loss, self.MLP_variables)
        
        self.t += 1
        for i in range(len(self.MLP_variables)):
            
            self.m[i].assign(self.beta1*self.m[i]+(1-self.beta1)*grads[i])
            self.v[i].assign(self.beta2*self.v[i]+(1-self.beta2)*grads[i]*grads[i])
            self.u[i].assign(self.beta3*self.u[i]+(1-self.beta3)*grads[i]*grads[i]*grads[i])
            
            
            m_hat = self.m[i]/(1-pow(self.beta1,self.t))
            v_hat = self.v[i]/(1-pow(self.beta2,self.t))
            u_hat = self.u[i]/(1-pow(self.beta3,self.t))
            
            update_var = self.MLP_variables[i] - learning_rate*m_hat/(tf.pow(v_hat, 1/2)+tf.sign(u_hat)*tf.pow(tf.abs(u_hat), 1/3)*pow(10,-8)+pow(10,-8))
            self.MLP_variables[i].assign(update_var)

        return current_loss, predicted
        
        
    def compute_output(self, X, dropout_rate=0):
        """
        Custom method to obtain output tensor during forward pass
        """
        # Cast X to float32
        X_tf = tf.cast(X, dtype=tf.float32)
        #Remember to normalize your dataset before moving forward
        # Compute values in hidden layer 1
        what = tf.matmul(X_tf, self.W1) + self.b1
        hhat = tf.nn.relu(what)
        # Implement Dropout
#         hhat = tf.nn.dropout(hhat, rate = dropout_rate, seed=seed)

        # Compute values in hidden layer 2
        what = tf.matmul(hhat, self.W2) + self.b2
        hhat = tf.nn.relu(what)
        # Implement Dropout
#         hhat = tf.nn.dropout(hhat, rate = dropout_rate, seed=seed)

        # Compute output
        output = tf.matmul(hhat, self.W3) + self.b3
        #Now consider two things , First look at inbuild loss functions if they work with softmax or not and then change this
        #Second add tf.Softmax(output) and then return this variable
        return tf.nn.softmax(output)
#         return output

# %%
result_for_ten = []
for s in range(10):
    print(s,"!!!!!!!!!!!!!!!!!")
    DROPOUT_RATE = 0
    BATCH_SIZE = 200
    HIDDEN_SIZE = 128
    NUM_EPOCHS = 20
    LEARNING_RATE = 0.001
    L2_PENLTY = 0

    current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    path = f"OPT-SELFALG_SEED_{s}-LearnRate_{LEARNING_RATE}-L2_{L2_PENLTY}-TIME_{current_time}"

#     Set log summary

    train_log_dir = 'logs/mnist_fashion/' + path + '/train'
    test_log_dir = 'logs/mnist_fashion/' + path + '/test'
#     train_log_dir = 'logs/mnist/' + path + '/train'
#     test_log_dir = 'logs/mnist/' + path + '/test'
    train_summary_writer = tf.summary.create_file_writer(train_log_dir)
    test_summary_writer = tf.summary.create_file_writer(test_log_dir)


    size_input = int(tf.shape(x_train)[1])
    size_hidden = HIDDEN_SIZE
    size_output = int(tf.shape(y_train)[1])
    number_of_train_examples = int(tf.shape(x_train)[0])
    number_of_test_examples = int(tf.shape(x_test)[0])


    # print("size_input",size_input)
    # print("size_output",size_output)
    # print("number_of_train_examples",number_of_train_examples)
    # print("number_of_test_examples",number_of_test_examples)


    mlp_on_gpu = MLP(size_input, size_hidden, size_output, device='cpu')
    time_start = time.time()
    epoch = 1
    loss_diff,last_loss = 1,0

    while epoch <= NUM_EPOCHS and abs(loss_diff) > 0.00001:
        loss_total_gpu = tf.zeros([1,1], dtype=tf.float32)
        train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(BATCH_SIZE+BATCH_SIZE//4, seed=epoch*(seed)).batch(BATCH_SIZE)
        for inputs, outputs in train_ds:
            cur_loss, preds = mlp_on_gpu.backward(inputs, outputs, dropout_rate=DROPOUT_RATE, learning_rate=LEARNING_RATE, L2=L2_PENLTY)
            loss_total_gpu += cur_loss
      # Calculate Accuracy
        train_accuracy, test_accuracy = tf.keras.metrics.CategoricalAccuracy(), tf.keras.metrics.CategoricalAccuracy()
        train_accuracy.update_state(y_train, mlp_on_gpu.forward(x_train))
        test_accuracy.update_state(y_test, mlp_on_gpu.forward(x_test))
        train_loss = np.sum(loss_total_gpu) / x_train.shape[0]
        test_loss = np.sum(mlp_on_gpu.loss(mlp_on_gpu.forward(x_test), y_test)) / x_test.shape[0]

        with train_summary_writer.as_default():
            tf.summary.scalar('loss', train_loss, step=epoch)
            tf.summary.scalar('accuracy', train_accuracy.result(), step=epoch)

        with test_summary_writer.as_default():
            tf.summary.scalar('loss', test_loss, step=epoch)
            tf.summary.scalar('accuracy', test_accuracy.result(), step=epoch)

        
        
        loss_diff = train_loss - last_loss
        last_loss = train_loss
        print(f'Number of Epoch = {epoch} - Training Cross Entropy:= {np.sum(loss_total_gpu) / x_train.shape[0]} - Training Accuracy:= {train_accuracy.result().numpy()} - Test Accuracy:= {test_accuracy.result().numpy()}')
        time_taken = time.time() - time_start
        print('Time taken (in seconds): {:.2f}'.format(time_taken))
        time_start = time.time()
        epoch += 1

    # record loss and accuracy for final test set:
    final_test_loss = np.sum(mlp_on_gpu.loss(mlp_on_gpu.forward(x_final_test), y_final_test)) / x_final_test.shape[0]
    final_test_acc = tf.keras.metrics.CategoricalAccuracy()
    final_test_acc.update_state(y_final_test, mlp_on_gpu.forward(x_final_test))
    result_for_ten.append([final_test_loss,final_test_acc.result().numpy()])
#     print(result_for_ten)
# Out:
# 0 !!!!!!!!!!!!!!!!!
# Number of Epoch = 1 - Training Cross Entropy:= 0.6361574609375 - Training Accuracy:= 0.8408200740814209 - Test Accuracy:= 0.8286000490188599
# Time taken (in seconds): 7.50
# Number of Epoch = 2 - Training Cross Entropy:= 0.419225 - Training Accuracy:= 0.8639600276947021 - Test Accuracy:= 0.8546000123023987
# Time taken (in seconds): 6.96
# Number of Epoch = 3 - Training Cross Entropy:= 0.368776875 - Training Accuracy:= 0.8731800317764282 - Test Accuracy:= 0.863800048828125
# Time taken (in seconds): 7.33
# Number of Epoch = 4 - Training Cross Entropy:= 0.341617890625 - Training Accuracy:= 0.8844600319862366 - Test Accuracy:= 0.8710000514984131
# Time taken (in seconds): 7.06
# Number of Epoch = 5 - Training Cross Entropy:= 0.31869255859375 - Training Accuracy:= 0.8883400559425354 - Test Accuracy:= 0.8717000484466553
# Time taken (in seconds): 7.20
# Number of Epoch = 6 - Training Cross Entropy:= 0.30041802734375 - Training Accuracy:= 0.8984400629997253 - Test Accuracy:= 0.8774000406265259
# Time taken (in seconds): 7.02
# Number of Epoch = 7 - Training Cross Entropy:= 0.28824943359375 - Training Accuracy:= 0.9031000733375549 - Test Accuracy:= 0.8802000284194946
# Time taken (in seconds): 7.09
# Number of Epoch = 8 - Training Cross Entropy:= 0.2733360546875 - Training Accuracy:= 0.9060400724411011 - Test Accuracy:= 0.8823000192642212
# Time taken (in seconds): 7.22
# Number of Epoch = 9 - Training Cross Entropy:= 0.26152529296875 - Training Accuracy:= 0.9092200398445129 - Test Accuracy:= 0.8836000561714172
# Time taken (in seconds): 6.91
# Number of Epoch = 10 - Training Cross Entropy:= 0.2529320703125 - Training Accuracy:= 0.9123400449752808 - Test Accuracy:= 0.8845000267028809
# Time taken (in seconds): 7.38
# Number of Epoch = 11 - Training Cross Entropy:= 0.24196173828125 - Training Accuracy:= 0.9153200387954712 - Test Accuracy:= 0.8863000273704529
# Time taken (in seconds): 6.96
# Number of Epoch = 12 - Training Cross Entropy:= 0.23392771484375 - Training Accuracy:= 0.9169200658798218 - Test Accuracy:= 0.8821000456809998
# Time taken (in seconds): 7.20
# Number of Epoch = 13 - Training Cross Entropy:= 0.22396015625 - Training Accuracy:= 0.9228200316429138 - Test Accuracy:= 0.886400043964386
# Time taken (in seconds): 7.09
# Number of Epoch = 14 - Training Cross Entropy:= 0.21558794921875 - Training Accuracy:= 0.9249000549316406 - Test Accuracy:= 0.8873000144958496
# Time taken (in seconds): 7.55
# Number of Epoch = 15 - Training Cross Entropy:= 0.20910568359375 - Training Accuracy:= 0.9223000407218933 - Test Accuracy:= 0.8868000507354736
# Time taken (in seconds): 7.40
# Number of Epoch = 16 - Training Cross Entropy:= 0.2043544140625 - Training Accuracy:= 0.9284000396728516 - Test Accuracy:= 0.8875000476837158
# Time taken (in seconds): 7.01
# Number of Epoch = 17 - Training Cross Entropy:= 0.1939646484375 - Training Accuracy:= 0.9297600388526917 - Test Accuracy:= 0.8875000476837158
# Time taken (in seconds): 7.24
# Number of Epoch = 18 - Training Cross Entropy:= 0.189163046875 - Training Accuracy:= 0.931320071220398 - Test Accuracy:= 0.8855000138282776
# Time taken (in seconds): 6.92
# Number of Epoch = 19 - Training Cross Entropy:= 0.181817578125 - Training Accuracy:= 0.932680070400238 - Test Accuracy:= 0.8875000476837158
# Time taken (in seconds): 7.26
# Number of Epoch = 20 - Training Cross Entropy:= 0.1769159765625 - Training Accuracy:= 0.936180055141449 - Test Accuracy:= 0.8885000348091125
# Time taken (in seconds): 7.16
# 1 !!!!!!!!!!!!!!!!!
# Number of Epoch = 1 - Training Cross Entropy:= 0.6405637890625 - Training Accuracy:= 0.8442400693893433 - Test Accuracy:= 0.8311000466346741
# Time taken (in seconds): 7.13
# Number of Epoch = 2 - Training Cross Entropy:= 0.418321171875 - Training Accuracy:= 0.8675400614738464 - Test Accuracy:= 0.8589000701904297
# Time taken (in seconds): 7.05
# Number of Epoch = 3 - Training Cross Entropy:= 0.367065234375 - Training Accuracy:= 0.875480055809021 - Test Accuracy:= 0.865600049495697
# Time taken (in seconds): 7.09
# Number of Epoch = 4 - Training Cross Entropy:= 0.3410544140625 - Training Accuracy:= 0.8867000341415405 - Test Accuracy:= 0.8753000497817993
# Time taken (in seconds): 7.22
# Number of Epoch = 5 - Training Cross Entropy:= 0.3163891015625 - Training Accuracy:= 0.8913800716400146 - Test Accuracy:= 0.8764000535011292
# Time taken (in seconds): 7.51
# Number of Epoch = 6 - Training Cross Entropy:= 0.2984244921875 - Training Accuracy:= 0.8980000615119934 - Test Accuracy:= 0.8824000358581543
# Time taken (in seconds): 7.61
# Number of Epoch = 7 - Training Cross Entropy:= 0.28295765625 - Training Accuracy:= 0.9032800793647766 - Test Accuracy:= 0.881100058555603
# Time taken (in seconds): 7.31
# Number of Epoch = 8 - Training Cross Entropy:= 0.2701319140625 - Training Accuracy:= 0.9062200784683228 - Test Accuracy:= 0.8809000253677368
# Time taken (in seconds): 7.98
# Number of Epoch = 9 - Training Cross Entropy:= 0.257900546875 - Training Accuracy:= 0.9111400842666626 - Test Accuracy:= 0.8825000524520874
# Time taken (in seconds): 7.31
# Number of Epoch = 10 - Training Cross Entropy:= 0.2498216015625 - Training Accuracy:= 0.9112000465393066 - Test Accuracy:= 0.885200023651123
# Time taken (in seconds): 7.66
# Number of Epoch = 11 - Training Cross Entropy:= 0.24014796875 - Training Accuracy:= 0.9141000509262085 - Test Accuracy:= 0.8841000199317932
# Time taken (in seconds): 7.16
# Number of Epoch = 12 - Training Cross Entropy:= 0.23131720703125 - Training Accuracy:= 0.9181200861930847 - Test Accuracy:= 0.886400043964386
# Time taken (in seconds): 7.08
# Number of Epoch = 13 - Training Cross Entropy:= 0.2202715625 - Training Accuracy:= 0.9225800633430481 - Test Accuracy:= 0.8884000182151794
# Time taken (in seconds): 6.85
# Number of Epoch = 14 - Training Cross Entropy:= 0.2134725390625 - Training Accuracy:= 0.9223800897598267 - Test Accuracy:= 0.8865000605583191
# Time taken (in seconds): 6.86
# Number of Epoch = 15 - Training Cross Entropy:= 0.207627890625 - Training Accuracy:= 0.9236000776290894 - Test Accuracy:= 0.885200023651123
# Time taken (in seconds): 6.67
# Number of Epoch = 16 - Training Cross Entropy:= 0.2000812890625 - Training Accuracy:= 0.9253800511360168 - Test Accuracy:= 0.8861000537872314
# Time taken (in seconds): 6.29
# Number of Epoch = 17 - Training Cross Entropy:= 0.1943891015625 - Training Accuracy:= 0.9292800426483154 - Test Accuracy:= 0.8886000514030457
# Time taken (in seconds): 6.43
# Number of Epoch = 18 - Training Cross Entropy:= 0.1882480859375 - Training Accuracy:= 0.9310400485992432 - Test Accuracy:= 0.8876000642776489
# Time taken (in seconds): 6.55
# Number of Epoch = 19 - Training Cross Entropy:= 0.1804633203125 - Training Accuracy:= 0.9301600456237793 - Test Accuracy:= 0.8884000182151794
# Time taken (in seconds): 6.40
# Number of Epoch = 20 - Training Cross Entropy:= 0.1766664453125 - Training Accuracy:= 0.9340600371360779 - Test Accuracy:= 0.8884000182151794
# Time taken (in seconds): 6.33
# 2 !!!!!!!!!!!!!!!!!
# Number of Epoch = 1 - Training Cross Entropy:= 0.631915859375 - Training Accuracy:= 0.8440600633621216 - Test Accuracy:= 0.8338000178337097
# Time taken (in seconds): 6.56
# Number of Epoch = 2 - Training Cross Entropy:= 0.4185296484375 - Training Accuracy:= 0.8654600381851196 - Test Accuracy:= 0.8561000227928162
# Time taken (in seconds): 6.48
# Number of Epoch = 3 - Training Cross Entropy:= 0.3678878515625 - Training Accuracy:= 0.8760000467300415 - Test Accuracy:= 0.8660000562667847
# Time taken (in seconds): 6.31
# Number of Epoch = 4 - Training Cross Entropy:= 0.33980578125 - Training Accuracy:= 0.8868200778961182 - Test Accuracy:= 0.8712000250816345
# Time taken (in seconds): 6.47
# Number of Epoch = 5 - Training Cross Entropy:= 0.315737734375 - Training Accuracy:= 0.8899000287055969 - Test Accuracy:= 0.875700056552887
# Time taken (in seconds): 6.57
# Number of Epoch = 6 - Training Cross Entropy:= 0.29767521484375 - Training Accuracy:= 0.8997800350189209 - Test Accuracy:= 0.8810000419616699
# Time taken (in seconds): 6.42
# Number of Epoch = 7 - Training Cross Entropy:= 0.28299751953125 - Training Accuracy:= 0.904740035533905 - Test Accuracy:= 0.8828000426292419
# Time taken (in seconds): 6.35
# Number of Epoch = 8 - Training Cross Entropy:= 0.2687099609375 - Training Accuracy:= 0.9076600670814514 - Test Accuracy:= 0.8828000426292419
# Time taken (in seconds): 6.56
# Number of Epoch = 9 - Training Cross Entropy:= 0.25737583984375 - Training Accuracy:= 0.9118000864982605 - Test Accuracy:= 0.8839000463485718
# Time taken (in seconds): 6.48
# Number of Epoch = 10 - Training Cross Entropy:= 0.248928046875 - Training Accuracy:= 0.9127200841903687 - Test Accuracy:= 0.8848000168800354
# Time taken (in seconds): 6.28
# Number of Epoch = 11 - Training Cross Entropy:= 0.241024453125 - Training Accuracy:= 0.9171200394630432 - Test Accuracy:= 0.8851000666618347
# Time taken (in seconds): 6.50
# Number of Epoch = 12 - Training Cross Entropy:= 0.231288828125 - Training Accuracy:= 0.9164400696754456 - Test Accuracy:= 0.8826000690460205
# Time taken (in seconds): 6.59
# Number of Epoch = 13 - Training Cross Entropy:= 0.2220045703125 - Training Accuracy:= 0.9248800873756409 - Test Accuracy:= 0.8873000144958496
# Time taken (in seconds): 6.36
# Number of Epoch = 14 - Training Cross Entropy:= 0.21379455078125 - Training Accuracy:= 0.9241800904273987 - Test Accuracy:= 0.8872000575065613
# Time taken (in seconds): 6.40
# Number of Epoch = 15 - Training Cross Entropy:= 0.20657908203125 - Training Accuracy:= 0.9234200716018677 - Test Accuracy:= 0.886400043964386
# Time taken (in seconds): 6.59
# Number of Epoch = 16 - Training Cross Entropy:= 0.2008403515625 - Training Accuracy:= 0.9285600781440735 - Test Accuracy:= 0.8881000280380249
# Time taken (in seconds): 6.43
# Number of Epoch = 17 - Training Cross Entropy:= 0.1921852734375 - Training Accuracy:= 0.930880069732666 - Test Accuracy:= 0.8847000598907471
# Time taken (in seconds): 6.29
# Number of Epoch = 18 - Training Cross Entropy:= 0.186257890625 - Training Accuracy:= 0.9308000802993774 - Test Accuracy:= 0.8833000659942627
# Time taken (in seconds): 6.49
# Number of Epoch = 19 - Training Cross Entropy:= 0.1785979296875 - Training Accuracy:= 0.932080090045929 - Test Accuracy:= 0.8833000659942627
# Time taken (in seconds): 6.59
# Number of Epoch = 20 - Training Cross Entropy:= 0.1719690625 - Training Accuracy:= 0.9346400499343872 - Test Accuracy:= 0.8833000659942627
# Time taken (in seconds): 6.31
# 3 !!!!!!!!!!!!!!!!!
# Number of Epoch = 1 - Training Cross Entropy:= 0.6356794921875 - Training Accuracy:= 0.8389000296592712 - Test Accuracy:= 0.8300000429153442
# Time taken (in seconds): 6.41
# Number of Epoch = 2 - Training Cross Entropy:= 0.4235162890625 - Training Accuracy:= 0.8668400645256042 - Test Accuracy:= 0.8534000515937805
# Time taken (in seconds): 6.54
# Number of Epoch = 3 - Training Cross Entropy:= 0.3730075390625 - Training Accuracy:= 0.8791200518608093 - Test Accuracy:= 0.8672000169754028
# Time taken (in seconds): 6.51
# Number of Epoch = 4 - Training Cross Entropy:= 0.346252578125 - Training Accuracy:= 0.8854600787162781 - Test Accuracy:= 0.870400071144104
# Time taken (in seconds): 6.33
# Number of Epoch = 5 - Training Cross Entropy:= 0.3220078515625 - Training Accuracy:= 0.8924400806427002 - Test Accuracy:= 0.8748000264167786
# Time taken (in seconds): 6.51
# Number of Epoch = 6 - Training Cross Entropy:= 0.3044150390625 - Training Accuracy:= 0.8977800607681274 - Test Accuracy:= 0.8803000450134277
# Time taken (in seconds): 6.47
# Number of Epoch = 7 - Training Cross Entropy:= 0.2901327734375 - Training Accuracy:= 0.9003000855445862 - Test Accuracy:= 0.8786000609397888
# Time taken (in seconds): 6.29
# Number of Epoch = 8 - Training Cross Entropy:= 0.2766048828125 - Training Accuracy:= 0.904740035533905 - Test Accuracy:= 0.8797000646591187
# Time taken (in seconds): 6.36
# Number of Epoch = 9 - Training Cross Entropy:= 0.26415046875 - Training Accuracy:= 0.9110800623893738 - Test Accuracy:= 0.8842000365257263
# Time taken (in seconds): 6.52
# Number of Epoch = 10 - Training Cross Entropy:= 0.25460171875 - Training Accuracy:= 0.9106000661849976 - Test Accuracy:= 0.8814000487327576
# Time taken (in seconds): 6.44
# Number of Epoch = 11 - Training Cross Entropy:= 0.24450306640625 - Training Accuracy:= 0.9132800698280334 - Test Accuracy:= 0.8843000531196594
# Time taken (in seconds): 6.56
# Number of Epoch = 12 - Training Cross Entropy:= 0.234681796875 - Training Accuracy:= 0.9156400561332703 - Test Accuracy:= 0.884600043296814
# Time taken (in seconds): 6.83
# Number of Epoch = 13 - Training Cross Entropy:= 0.2254834765625 - Training Accuracy:= 0.9216200709342957 - Test Accuracy:= 0.8881000280380249
# Time taken (in seconds): 6.85
# Number of Epoch = 14 - Training Cross Entropy:= 0.21803658203125 - Training Accuracy:= 0.9236600399017334 - Test Accuracy:= 0.8863000273704529
# Time taken (in seconds): 6.36
# Number of Epoch = 15 - Training Cross Entropy:= 0.21124794921875 - Training Accuracy:= 0.9245800375938416 - Test Accuracy:= 0.8832000494003296
# Time taken (in seconds): 6.59
# Number of Epoch = 16 - Training Cross Entropy:= 0.20843873046875 - Training Accuracy:= 0.9287400841712952 - Test Accuracy:= 0.8859000205993652
# Time taken (in seconds): 6.50
# Number of Epoch = 17 - Training Cross Entropy:= 0.19792630859375 - Training Accuracy:= 0.9299800395965576 - Test Accuracy:= 0.8856000304222107
# Time taken (in seconds): 6.26
# Number of Epoch = 18 - Training Cross Entropy:= 0.190489765625 - Training Accuracy:= 0.9309000372886658 - Test Accuracy:= 0.8861000537872314
# Time taken (in seconds): 6.46
# Number of Epoch = 19 - Training Cross Entropy:= 0.1843152734375 - Training Accuracy:= 0.9295600652694702 - Test Accuracy:= 0.8839000463485718
# Time taken (in seconds): 6.81
# Number of Epoch = 20 - Training Cross Entropy:= 0.1775578125 - Training Accuracy:= 0.935460090637207 - Test Accuracy:= 0.8857000470161438
# Time taken (in seconds): 6.51
# 4 !!!!!!!!!!!!!!!!!
# Number of Epoch = 1 - Training Cross Entropy:= 0.6271714453125 - Training Accuracy:= 0.8423000574111938 - Test Accuracy:= 0.829300045967102
# Time taken (in seconds): 6.93
# Number of Epoch = 2 - Training Cross Entropy:= 0.41942984375 - Training Accuracy:= 0.866640031337738 - Test Accuracy:= 0.8548000454902649
# Time taken (in seconds): 6.65
# Number of Epoch = 3 - Training Cross Entropy:= 0.3650546875 - Training Accuracy:= 0.8785800337791443 - Test Accuracy:= 0.8657000660896301
# Time taken (in seconds): 6.30
# Number of Epoch = 4 - Training Cross Entropy:= 0.3390231640625 - Training Accuracy:= 0.8860600590705872 - Test Accuracy:= 0.8708000183105469
# Time taken (in seconds): 6.41
# Number of Epoch = 5 - Training Cross Entropy:= 0.31600828125 - Training Accuracy:= 0.8942400813102722 - Test Accuracy:= 0.8755000233650208
# Time taken (in seconds): 6.54
# Number of Epoch = 6 - Training Cross Entropy:= 0.29689107421875 - Training Accuracy:= 0.8995600342750549 - Test Accuracy:= 0.8802000284194946
# Time taken (in seconds): 6.37
# Number of Epoch = 7 - Training Cross Entropy:= 0.284071171875 - Training Accuracy:= 0.9045600891113281 - Test Accuracy:= 0.882900059223175
# Time taken (in seconds): 6.29
# Number of Epoch = 8 - Training Cross Entropy:= 0.2689525390625 - Training Accuracy:= 0.9079000353813171 - Test Accuracy:= 0.886400043964386
# Time taken (in seconds): 6.57
# Number of Epoch = 9 - Training Cross Entropy:= 0.25755498046875 - Training Accuracy:= 0.9110600352287292 - Test Accuracy:= 0.8849000334739685
# Time taken (in seconds): 6.47
# Number of Epoch = 10 - Training Cross Entropy:= 0.2476040625 - Training Accuracy:= 0.9110600352287292 - Test Accuracy:= 0.883400022983551
# Time taken (in seconds): 6.30
# Number of Epoch = 11 - Training Cross Entropy:= 0.2382617578125 - Training Accuracy:= 0.9193600416183472 - Test Accuracy:= 0.8898000717163086
# Time taken (in seconds): 6.51
# Number of Epoch = 12 - Training Cross Entropy:= 0.227054921875 - Training Accuracy:= 0.9199400544166565 - Test Accuracy:= 0.8871000409126282
# Time taken (in seconds): 6.59
# Number of Epoch = 13 - Training Cross Entropy:= 0.2180234765625 - Training Accuracy:= 0.9249600768089294 - Test Accuracy:= 0.8891000151634216
# Time taken (in seconds): 6.56
# Number of Epoch = 14 - Training Cross Entropy:= 0.2103639453125 - Training Accuracy:= 0.9267000555992126 - Test Accuracy:= 0.8878000378608704
# Time taken (in seconds): 6.83
# Number of Epoch = 15 - Training Cross Entropy:= 0.201864453125 - Training Accuracy:= 0.924720048904419 - Test Accuracy:= 0.8871000409126282
# Time taken (in seconds): 7.29
# Number of Epoch = 16 - Training Cross Entropy:= 0.19557015625 - Training Accuracy:= 0.9262600541114807 - Test Accuracy:= 0.884600043296814
# Time taken (in seconds): 6.77
# Number of Epoch = 17 - Training Cross Entropy:= 0.18955412109375 - Training Accuracy:= 0.9303000569343567 - Test Accuracy:= 0.8890000581741333
# Time taken (in seconds): 6.80
# Number of Epoch = 18 - Training Cross Entropy:= 0.18356037109375 - Training Accuracy:= 0.9301600456237793 - Test Accuracy:= 0.8858000636100769
# Time taken (in seconds): 6.47
# Number of Epoch = 19 - Training Cross Entropy:= 0.175531640625 - Training Accuracy:= 0.9346200823783875 - Test Accuracy:= 0.8908000588417053
# Time taken (in seconds): 6.29
# Number of Epoch = 20 - Training Cross Entropy:= 0.1703946484375 - Training Accuracy:= 0.9366400837898254 - Test Accuracy:= 0.8895000219345093
# Time taken (in seconds): 6.51
# 5 !!!!!!!!!!!!!!!!!
# Number of Epoch = 1 - Training Cross Entropy:= 0.675336796875 - Training Accuracy:= 0.8413400650024414 - Test Accuracy:= 0.8336000442504883
# Time taken (in seconds): 6.56
# Number of Epoch = 2 - Training Cross Entropy:= 0.4229575390625 - Training Accuracy:= 0.8660600781440735 - Test Accuracy:= 0.8559000492095947
# Time taken (in seconds): 6.34
# Number of Epoch = 3 - Training Cross Entropy:= 0.36898203125 - Training Accuracy:= 0.8757800459861755 - Test Accuracy:= 0.8651000261306763
# Time taken (in seconds): 6.41
# Number of Epoch = 4 - Training Cross Entropy:= 0.3395371484375 - Training Accuracy:= 0.8873400688171387 - Test Accuracy:= 0.8718000650405884
# Time taken (in seconds): 6.55
# Number of Epoch = 5 - Training Cross Entropy:= 0.31588251953125 - Training Accuracy:= 0.8894600868225098 - Test Accuracy:= 0.8750000596046448
# Time taken (in seconds): 6.45
# Number of Epoch = 6 - Training Cross Entropy:= 0.2978324609375 - Training Accuracy:= 0.8997600674629211 - Test Accuracy:= 0.8817000389099121
# Time taken (in seconds): 6.34
# Number of Epoch = 7 - Training Cross Entropy:= 0.283213515625 - Training Accuracy:= 0.9017600417137146 - Test Accuracy:= 0.881600022315979
# Time taken (in seconds): 6.52
# Number of Epoch = 8 - Training Cross Entropy:= 0.2694605078125 - Training Accuracy:= 0.9047000408172607 - Test Accuracy:= 0.881600022315979
# Time taken (in seconds): 6.55
# Number of Epoch = 9 - Training Cross Entropy:= 0.25889470703125 - Training Accuracy:= 0.9113600850105286 - Test Accuracy:= 0.8868000507354736
# Time taken (in seconds): 6.41
# Number of Epoch = 10 - Training Cross Entropy:= 0.2477116796875 - Training Accuracy:= 0.9117200374603271 - Test Accuracy:= 0.8861000537872314
# Time taken (in seconds): 6.43
# Number of Epoch = 11 - Training Cross Entropy:= 0.238833828125 - Training Accuracy:= 0.912100076675415 - Test Accuracy:= 0.8843000531196594
# Time taken (in seconds): 6.53
# Number of Epoch = 12 - Training Cross Entropy:= 0.2310018359375 - Training Accuracy:= 0.9152800440788269 - Test Accuracy:= 0.8888000249862671
# Time taken (in seconds): 6.47
# Number of Epoch = 13 - Training Cross Entropy:= 0.22101064453125 - Training Accuracy:= 0.91920006275177 - Test Accuracy:= 0.8862000703811646
# Time taken (in seconds): 6.33
# Number of Epoch = 14 - Training Cross Entropy:= 0.2121090234375 - Training Accuracy:= 0.9202200770378113 - Test Accuracy:= 0.8869000673294067
# Time taken (in seconds): 6.51
# Number of Epoch = 15 - Training Cross Entropy:= 0.206657578125 - Training Accuracy:= 0.9218600392341614 - Test Accuracy:= 0.8865000605583191
# Time taken (in seconds): 6.55
# Number of Epoch = 16 - Training Cross Entropy:= 0.2030325390625 - Training Accuracy:= 0.9267600774765015 - Test Accuracy:= 0.8878000378608704
# Time taken (in seconds): 6.33
# Number of Epoch = 17 - Training Cross Entropy:= 0.1936424609375 - Training Accuracy:= 0.9263400435447693 - Test Accuracy:= 0.8838000297546387
# Time taken (in seconds): 6.46
# Number of Epoch = 18 - Training Cross Entropy:= 0.18669427734375 - Training Accuracy:= 0.9262600541114807 - Test Accuracy:= 0.8820000290870667
# Time taken (in seconds): 6.63
# Number of Epoch = 19 - Training Cross Entropy:= 0.18097650390625 - Training Accuracy:= 0.9265600442886353 - Test Accuracy:= 0.8871000409126282
# Time taken (in seconds): 6.37
# Number of Epoch = 20 - Training Cross Entropy:= 0.1746653515625 - Training Accuracy:= 0.9309200644493103 - Test Accuracy:= 0.884600043296814
# Time taken (in seconds): 6.36
# 6 !!!!!!!!!!!!!!!!!
# Number of Epoch = 1 - Training Cross Entropy:= 0.627609765625 - Training Accuracy:= 0.8442800641059875 - Test Accuracy:= 0.8331000208854675
# Time taken (in seconds): 6.58
# Number of Epoch = 2 - Training Cross Entropy:= 0.412977578125 - Training Accuracy:= 0.870460033416748 - Test Accuracy:= 0.8591000437736511
# Time taken (in seconds): 6.51
# Number of Epoch = 3 - Training Cross Entropy:= 0.3638553125 - Training Accuracy:= 0.8791400790214539 - Test Accuracy:= 0.8689000606536865
# Time taken (in seconds): 6.30
# Number of Epoch = 4 - Training Cross Entropy:= 0.336656796875 - Training Accuracy:= 0.8872200846672058 - Test Accuracy:= 0.8714000582695007
# Time taken (in seconds): 6.54
# Number of Epoch = 5 - Training Cross Entropy:= 0.31360955078125 - Training Accuracy:= 0.8916200399398804 - Test Accuracy:= 0.8746000528335571
# Time taken (in seconds): 6.53
# Number of Epoch = 6 - Training Cross Entropy:= 0.2971580859375 - Training Accuracy:= 0.8995600342750549 - Test Accuracy:= 0.8812000155448914
# Time taken (in seconds): 6.30
# Number of Epoch = 7 - Training Cross Entropy:= 0.281566015625 - Training Accuracy:= 0.9037800431251526 - Test Accuracy:= 0.8812000155448914
# Time taken (in seconds): 6.40
# Number of Epoch = 8 - Training Cross Entropy:= 0.26857404296875 - Training Accuracy:= 0.9081000685691833 - Test Accuracy:= 0.8831000328063965
# Time taken (in seconds): 6.61
# Number of Epoch = 9 - Training Cross Entropy:= 0.2565736328125 - Training Accuracy:= 0.9128600358963013 - Test Accuracy:= 0.8847000598907471
# Time taken (in seconds): 6.42
# Number of Epoch = 10 - Training Cross Entropy:= 0.246842265625 - Training Accuracy:= 0.9172400832176208 - Test Accuracy:= 0.8885000348091125
# Time taken (in seconds): 6.35
# Number of Epoch = 11 - Training Cross Entropy:= 0.2381706640625 - Training Accuracy:= 0.9173600673675537 - Test Accuracy:= 0.885200023651123
# Time taken (in seconds): 6.52
# Number of Epoch = 12 - Training Cross Entropy:= 0.227544375 - Training Accuracy:= 0.9222200512886047 - Test Accuracy:= 0.8889000415802002
# Time taken (in seconds): 6.51
# Number of Epoch = 13 - Training Cross Entropy:= 0.218807734375 - Training Accuracy:= 0.9233600497245789 - Test Accuracy:= 0.8885000348091125
# Time taken (in seconds): 6.43
# Number of Epoch = 14 - Training Cross Entropy:= 0.21033609375 - Training Accuracy:= 0.9263200759887695 - Test Accuracy:= 0.8897000551223755
# Time taken (in seconds): 6.74
# Number of Epoch = 15 - Training Cross Entropy:= 0.20338046875 - Training Accuracy:= 0.9267600774765015 - Test Accuracy:= 0.8866000175476074
# Time taken (in seconds): 6.97
# Number of Epoch = 16 - Training Cross Entropy:= 0.19790646484375 - Training Accuracy:= 0.9306200742721558 - Test Accuracy:= 0.8890000581741333
# Time taken (in seconds): 7.11
# Number of Epoch = 17 - Training Cross Entropy:= 0.1879670703125 - Training Accuracy:= 0.9323400855064392 - Test Accuracy:= 0.889400064945221
# Time taken (in seconds): 7.66
# Number of Epoch = 18 - Training Cross Entropy:= 0.183297890625 - Training Accuracy:= 0.9315600395202637 - Test Accuracy:= 0.8842000365257263
# Time taken (in seconds): 6.86
# Number of Epoch = 19 - Training Cross Entropy:= 0.175674765625 - Training Accuracy:= 0.9330800771713257 - Test Accuracy:= 0.8866000175476074
# Time taken (in seconds): 7.26
# Number of Epoch = 20 - Training Cross Entropy:= 0.1693701171875 - Training Accuracy:= 0.934980034828186 - Test Accuracy:= 0.8856000304222107
# Time taken (in seconds): 7.17
# 7 !!!!!!!!!!!!!!!!!
# Number of Epoch = 1 - Training Cross Entropy:= 0.6214821484375 - Training Accuracy:= 0.8471800684928894 - Test Accuracy:= 0.8365000486373901
# Time taken (in seconds): 7.19
# Number of Epoch = 2 - Training Cross Entropy:= 0.415459375 - Training Accuracy:= 0.8675400614738464 - Test Accuracy:= 0.8586000204086304
# Time taken (in seconds): 7.10
# Number of Epoch = 3 - Training Cross Entropy:= 0.36631546875 - Training Accuracy:= 0.8746000528335571 - Test Accuracy:= 0.8685000538825989
# Time taken (in seconds): 7.12
# Number of Epoch = 4 - Training Cross Entropy:= 0.33818125 - Training Accuracy:= 0.8857800364494324 - Test Accuracy:= 0.8749000430107117
# Time taken (in seconds): 7.72
# Number of Epoch = 5 - Training Cross Entropy:= 0.31472658203125 - Training Accuracy:= 0.8920600414276123 - Test Accuracy:= 0.8759000301361084
# Time taken (in seconds): 7.49
# Number of Epoch = 6 - Training Cross Entropy:= 0.296533203125 - Training Accuracy:= 0.8987800478935242 - Test Accuracy:= 0.8806000351905823
# Time taken (in seconds): 7.25
# Number of Epoch = 7 - Training Cross Entropy:= 0.2819271875 - Training Accuracy:= 0.9036000370979309 - Test Accuracy:= 0.8820000290870667
# Time taken (in seconds): 6.94
# Number of Epoch = 8 - Training Cross Entropy:= 0.26929544921875 - Training Accuracy:= 0.9053200483322144 - Test Accuracy:= 0.8824000358581543
# Time taken (in seconds): 7.37
# Number of Epoch = 9 - Training Cross Entropy:= 0.25708189453125 - Training Accuracy:= 0.9116800427436829 - Test Accuracy:= 0.8859000205993652
# Time taken (in seconds): 6.95
# Number of Epoch = 10 - Training Cross Entropy:= 0.2481984765625 - Training Accuracy:= 0.9163200855255127 - Test Accuracy:= 0.8884000182151794
# Time taken (in seconds): 7.34
# Number of Epoch = 11 - Training Cross Entropy:= 0.2388930859375 - Training Accuracy:= 0.9121800661087036 - Test Accuracy:= 0.8820000290870667
# Time taken (in seconds): 7.66
# Number of Epoch = 12 - Training Cross Entropy:= 0.229016171875 - Training Accuracy:= 0.9193000793457031 - Test Accuracy:= 0.8858000636100769
# Time taken (in seconds): 7.18
# Number of Epoch = 13 - Training Cross Entropy:= 0.21940265625 - Training Accuracy:= 0.9209800362586975 - Test Accuracy:= 0.8863000273704529
# Time taken (in seconds): 7.32
# Number of Epoch = 14 - Training Cross Entropy:= 0.21196474609375 - Training Accuracy:= 0.9241600632667542 - Test Accuracy:= 0.8871000409126282
# Time taken (in seconds): 7.30
# Number of Epoch = 15 - Training Cross Entropy:= 0.20766240234375 - Training Accuracy:= 0.9250600337982178 - Test Accuracy:= 0.8866000175476074
# Time taken (in seconds): 7.31
# Number of Epoch = 16 - Training Cross Entropy:= 0.2015433984375 - Training Accuracy:= 0.9272200465202332 - Test Accuracy:= 0.8865000605583191
# Time taken (in seconds): 7.13
# Number of Epoch = 17 - Training Cross Entropy:= 0.19365734375 - Training Accuracy:= 0.928540050983429 - Test Accuracy:= 0.8868000507354736
# Time taken (in seconds): 7.46
# Number of Epoch = 18 - Training Cross Entropy:= 0.1867115234375 - Training Accuracy:= 0.9308000802993774 - Test Accuracy:= 0.8872000575065613
# Time taken (in seconds): 7.08
# Number of Epoch = 19 - Training Cross Entropy:= 0.1815552734375 - Training Accuracy:= 0.9327200651168823 - Test Accuracy:= 0.8890000581741333
# Time taken (in seconds): 7.27
# Number of Epoch = 20 - Training Cross Entropy:= 0.17613365234375 - Training Accuracy:= 0.9346600770950317 - Test Accuracy:= 0.8872000575065613
# Time taken (in seconds): 7.05
# 8 !!!!!!!!!!!!!!!!!
# Number of Epoch = 1 - Training Cross Entropy:= 0.62386890625 - Training Accuracy:= 0.8461600542068481 - Test Accuracy:= 0.8347000479698181
# Time taken (in seconds): 7.42
# Number of Epoch = 2 - Training Cross Entropy:= 0.4110079296875 - Training Accuracy:= 0.8680000305175781 - Test Accuracy:= 0.8570000529289246
# Time taken (in seconds): 7.04
# Number of Epoch = 3 - Training Cross Entropy:= 0.3622821875 - Training Accuracy:= 0.880060076713562 - Test Accuracy:= 0.867900013923645
# Time taken (in seconds): 7.34
# Number of Epoch = 4 - Training Cross Entropy:= 0.3388981640625 - Training Accuracy:= 0.8878000378608704 - Test Accuracy:= 0.8718000650405884
# Time taken (in seconds): 7.20
# Number of Epoch = 5 - Training Cross Entropy:= 0.31584875 - Training Accuracy:= 0.8908000588417053 - Test Accuracy:= 0.875700056552887
# Time taken (in seconds): 7.08
# Number of Epoch = 6 - Training Cross Entropy:= 0.2981317578125 - Training Accuracy:= 0.8975200653076172 - Test Accuracy:= 0.8784000277519226
# Time taken (in seconds): 7.51
# Number of Epoch = 7 - Training Cross Entropy:= 0.2839787890625 - Training Accuracy:= 0.90392005443573 - Test Accuracy:= 0.8795000314712524
# Time taken (in seconds): 7.02
# Number of Epoch = 8 - Training Cross Entropy:= 0.26984220703125 - Training Accuracy:= 0.9052000641822815 - Test Accuracy:= 0.8797000646591187
# Time taken (in seconds): 7.23
# Number of Epoch = 9 - Training Cross Entropy:= 0.25914869140625 - Training Accuracy:= 0.9116000533103943 - Test Accuracy:= 0.884600043296814
# Time taken (in seconds): 7.09
# Number of Epoch = 10 - Training Cross Entropy:= 0.25051625 - Training Accuracy:= 0.9141400456428528 - Test Accuracy:= 0.8840000629425049
# Time taken (in seconds): 7.76
# Number of Epoch = 11 - Training Cross Entropy:= 0.2404351171875 - Training Accuracy:= 0.9173000454902649 - Test Accuracy:= 0.8855000138282776
# Time taken (in seconds): 7.06
# Number of Epoch = 12 - Training Cross Entropy:= 0.23176294921875 - Training Accuracy:= 0.9173600673675537 - Test Accuracy:= 0.8848000168800354
# Time taken (in seconds): 7.33
# Number of Epoch = 13 - Training Cross Entropy:= 0.22064384765625 - Training Accuracy:= 0.9226200580596924 - Test Accuracy:= 0.8856000304222107
# Time taken (in seconds): 7.11
# Number of Epoch = 14 - Training Cross Entropy:= 0.212502890625 - Training Accuracy:= 0.9252400398254395 - Test Accuracy:= 0.8890000581741333
# Time taken (in seconds): 7.18
# Number of Epoch = 15 - Training Cross Entropy:= 0.20725482421875 - Training Accuracy:= 0.9227200746536255 - Test Accuracy:= 0.8836000561714172
# Time taken (in seconds): 7.26
# Number of Epoch = 16 - Training Cross Entropy:= 0.199138515625 - Training Accuracy:= 0.9294200539588928 - Test Accuracy:= 0.8870000243186951
# Time taken (in seconds): 7.01
# Number of Epoch = 17 - Training Cross Entropy:= 0.190629609375 - Training Accuracy:= 0.9279400706291199 - Test Accuracy:= 0.8858000636100769
# Time taken (in seconds): 7.26
# Number of Epoch = 18 - Training Cross Entropy:= 0.185769375 - Training Accuracy:= 0.9323400855064392 - Test Accuracy:= 0.8868000507354736
# Time taken (in seconds): 6.92
# Number of Epoch = 19 - Training Cross Entropy:= 0.178406953125 - Training Accuracy:= 0.9358800649642944 - Test Accuracy:= 0.889400064945221
# Time taken (in seconds): 7.17
# Number of Epoch = 20 - Training Cross Entropy:= 0.172336796875 - Training Accuracy:= 0.936180055141449 - Test Accuracy:= 0.8858000636100769
# Time taken (in seconds): 7.26
# 9 !!!!!!!!!!!!!!!!!
# Number of Epoch = 1 - Training Cross Entropy:= 0.6278451171875 - Training Accuracy:= 0.8405600786209106 - Test Accuracy:= 0.830500066280365
# Time taken (in seconds): 7.02
# Number of Epoch = 2 - Training Cross Entropy:= 0.414601328125 - Training Accuracy:= 0.8672600388526917 - Test Accuracy:= 0.85670006275177
# Time taken (in seconds): 7.17
# Number of Epoch = 3 - Training Cross Entropy:= 0.363908671875 - Training Accuracy:= 0.8791600465774536 - Test Accuracy:= 0.8624000549316406
# Time taken (in seconds): 7.27
# Number of Epoch = 4 - Training Cross Entropy:= 0.3395866796875 - Training Accuracy:= 0.886120080947876 - Test Accuracy:= 0.8693000674247742
# Time taken (in seconds): 7.33
# Number of Epoch = 5 - Training Cross Entropy:= 0.315693359375 - Training Accuracy:= 0.8925600647926331 - Test Accuracy:= 0.8716000318527222
# Time taken (in seconds): 7.01
# Number of Epoch = 6 - Training Cross Entropy:= 0.29704986328125 - Training Accuracy:= 0.8986600637435913 - Test Accuracy:= 0.8759000301361084
# Time taken (in seconds): 7.48
# Number of Epoch = 7 - Training Cross Entropy:= 0.283117890625 - Training Accuracy:= 0.9030600786209106 - Test Accuracy:= 0.8790000677108765
# Time taken (in seconds): 7.00
# Number of Epoch = 8 - Training Cross Entropy:= 0.26960890625 - Training Accuracy:= 0.9035600423812866 - Test Accuracy:= 0.8788000345230103
# Time taken (in seconds): 7.21
# Number of Epoch = 9 - Training Cross Entropy:= 0.25791896484375 - Training Accuracy:= 0.9095600843429565 - Test Accuracy:= 0.8824000358581543
# Time taken (in seconds): 7.16
# Number of Epoch = 10 - Training Cross Entropy:= 0.251520234375 - Training Accuracy:= 0.9133000373840332 - Test Accuracy:= 0.8838000297546387
# Time taken (in seconds): 7.09
# Number of Epoch = 11 - Training Cross Entropy:= 0.239065703125 - Training Accuracy:= 0.909320056438446 - Test Accuracy:= 0.8787000179290771
# Time taken (in seconds): 7.33
# Number of Epoch = 12 - Training Cross Entropy:= 0.23133193359375 - Training Accuracy:= 0.915160059928894 - Test Accuracy:= 0.881600022315979
# Time taken (in seconds): 7.06
# Number of Epoch = 13 - Training Cross Entropy:= 0.2218828125 - Training Accuracy:= 0.9195600748062134 - Test Accuracy:= 0.8837000131607056
# Time taken (in seconds): 7.40
# Number of Epoch = 14 - Training Cross Entropy:= 0.2131425390625 - Training Accuracy:= 0.9230000376701355 - Test Accuracy:= 0.882900059223175
# Time taken (in seconds): 7.00
# Number of Epoch = 15 - Training Cross Entropy:= 0.2072130859375 - Training Accuracy:= 0.9230000376701355 - Test Accuracy:= 0.8820000290870667
# Time taken (in seconds): 7.49
# Number of Epoch = 16 - Training Cross Entropy:= 0.201791875 - Training Accuracy:= 0.9254600405693054 - Test Accuracy:= 0.8819000124931335
# Time taken (in seconds): 7.16
# Number of Epoch = 17 - Training Cross Entropy:= 0.194202890625 - Training Accuracy:= 0.9286400675773621 - Test Accuracy:= 0.8826000690460205
# Time taken (in seconds): 7.14
# Number of Epoch = 18 - Training Cross Entropy:= 0.18708087890625 - Training Accuracy:= 0.9291800856590271 - Test Accuracy:= 0.886400043964386
# Time taken (in seconds): 7.20
# Number of Epoch = 19 - Training Cross Entropy:= 0.1820428125 - Training Accuracy:= 0.9332000613212585 - Test Accuracy:= 0.886400043964386
# Time taken (in seconds): 7.33
# Number of Epoch = 20 - Training Cross Entropy:= 0.1753690234375 - Training Accuracy:= 0.9348400831222534 - Test Accuracy:= 0.8861000537872314
# Time taken (in seconds): 7.53

# %%
result_for_ten
# Out:
# [[0.366101904296875, 0.88280004],
#  [0.372931298828125, 0.88280004],
#  [0.379409130859375, 0.88030005],
#  [0.363632275390625, 0.88310003],
#  [0.375222216796875, 0.88110006],
#  [0.3708097412109375, 0.8801001],
#  [0.372384619140625, 0.8823],
#  [0.3681942138671875, 0.88220006],
#  [0.365265966796875, 0.8834],
#  [0.36305341796875, 0.88060004]]

# %%
print(sum(map(lambda x: x[0], result_for_ten))/len(result_for_ten),
      sum(map(lambda x: x[1], result_for_ten))/len(result_for_ten))
# Out:
# 0.369700478515625 0.8818700432777404
